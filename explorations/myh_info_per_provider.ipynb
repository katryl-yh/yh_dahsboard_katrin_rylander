# %% [markdown]
# ### Resultat för kurser (YH-utbildningar upp till 99 poäng)
# #### Filter out data and show statistics per education provider

# %% [markdown]
# ##### Filtrera ut data
# ##### Använd filtrena för att filtrera:
# - utbildningsområde,
# - kommun,
# - skola
#
# - Notera att det saknas skolor och kurser för en del kombinationer av utbildningsområde och kommun.

# %%
import os
import pandas as pd

def load_file_for_year(folder_path, year):
    """
    Loads the Excel file for the given year from the specified folder.
    Returns a pandas DataFrame or None if not found.
    """
    year_str = str(year)
    files = os.listdir(folder_path)
    matched_files = [
        f for f in files
        if year_str in f and 'resultat' in f.lower() and f.endswith('.xlsx')
    ]

    if not matched_files:
        print(f"No files found for year {year}")
        return None

    if len(matched_files) > 1:
        print(f"Warning: Multiple files matched for year {year}: {matched_files}")
        return None

    filename = matched_files[0]
    filepath = os.path.join(folder_path, filename)
    print(f"Loading data from: {filename}")
    df = pd.read_excel(filepath)
    return df

# Set your folder path here
folder = '../data/resultat_kurser'
selected_year = 2025  # change this as needed

df = load_file_for_year(folder, selected_year)

if df is not None:
    print(f"Data shape: {df.shape}")
    display(df.head())
else:
    print("No data found.")
# Out:
# Loading data from: resultat-2025-for-kurser-inom-yh.xlsx
# Data shape: (1026, 15)
#     Diarienummer    Beslut                              Anordnare namn  \
# 0  MYH 2025/1001    Avslag  Härryda kommun, Yrkeshögskolan i Mölnlycke
# 1  MYH 2025/1002  Beviljad               TUC Sweden AB - Yrkeshögskola
# 2  MYH 2025/1003  Beviljad             IHM Business School AB Göteborg
# 3  MYH 2025/1004  Beviljad                    Lexicon Yrkeshögskola AB
# 4  MYH 2025/1005  Beviljad                    Lexicon Yrkeshögskola AB
#
#                                      Utbildningsnamn  \
# 0               Frihandel och ursprung - fördjupning
# 1  IT- och informationssäkerhet för administrativ...
# 2      Digital redovisning & hållbarhetsrapportering
# 3                     Digitalisera dina utbildningar
# 4                    Producera digitala utbildningar
#
#                          Utbildningsområde  \
# 0  Ekonomi, administration och försäljning
# 1                                  Data/IT
# 2  Ekonomi, administration och försäljning
# 3               Pedagogik och undervisning
# 4                 Kultur, media och design
#
#    Antal beviljade platser start 2025  Antal beviljade platser start 2026  \
# 0                                   0                                   0
# 1                                  30                                  30
# 2                                  40                                  40
# 3                                  35                                  35
# 4                                  35                                   0
#
#    Totalt antal beviljade platser  YH-poäng                     Kommun  \
# 0                               0        30                    Härryda
# 1                              60        30  Se "Lista flera kommuner"
# 2                              80        30                   Göteborg
# 3                              70        50                  Stockholm
# 4                              35        50                  Stockholm
#
#                          Län                  FA-region  Antal kommuner  \
# 0            Västra Götaland                   Göteborg               1
# 1  Se "Lista flera kommuner"  Se "Lista flera kommuner"               5
# 2            Västra Götaland                   Göteborg               1
# 3                  Stockholm                  Stockholm               1
# 4                  Stockholm                  Stockholm               1
#
#    Antal län  Antal FA-regioner
# 0          1                  1
# 1          5                  5
# 2          1                  1
# 3          1                  1
# 4          1                  1

# %% [markdown]
# ##### There are two main functions:
#
# filter_and_show_schools:
# - Core filtering function that returns a DataFrame
# show_filtered_schools:
# - Helper function that handles display formatting
#
#
# Key features:
#
# - Flexible filtering: Use any combination of filters
# - Clear column names in Swedish
# - Sorted output by school and course name
# - Styled display with pandas
# - Shows available filter options
# - Error handling for no results
# - Shows filter criteria in output

# %%
# Check the column names
print("Available columns in DataFrame:")
for col in df.columns:
    print(f"- {col}")
# Out:
# Available columns in DataFrame:
# - Diarienummer
# - Beslut
# - Anordnare namn
# - Utbildningsnamn
# - Utbildningsområde
# - Antal beviljade platser start 2025
# - Antal beviljade platser start 2026
# - Totalt antal beviljade platser
# - YH-poäng
# - Kommun
# - Län
# - FA-region
# - Antal kommuner
# - Antal län
# - Antal FA-regioner

# %%
def show_filtered_schools(df: pd.DataFrame,
                        education_area: str = None,
                        county: str = None,
                        municipality: str = None) -> None:
    """
    Display filtered school and course information with formatting.
    """
    result = filter_and_show_schools(df, education_area, county, municipality)
    
    if result.empty:
        print("Inga resultat hittades med angivna filter.")
        return
    
    print(f"\nHittade {len(result)} kurser")
    print(f"Filter: ", end="")
    if education_area:
        print(f"\n - Utbildningsområde: {education_area}", end="")
    if county:
        print(f"\n - Län: {county}", end="")
    if municipality:
        print(f"\n - Kommun: {municipality}", end="")
    print("\n")
    
    # Updated display formatting using current pandas syntax
    display(result.style
           .set_properties(**{
               'background-color': 'white',
               'color': 'black',
               'border-color': '#888'
           })
           .hide(axis='index')  # New syntax for hiding index
    )

# Example usage:
print("Available education areas:")
print(df['Utbildningsområde'].unique())
print("\nAvailable counties:")
print(df['Län'].unique())

# Filter example
show_filtered_schools(
    df,
    education_area="Data/IT",
    county="Stockholm",
    municipality="Stockholm"
)
# Out:
# Available education areas:
# ['Ekonomi, administration och försäljning' 'Data/IT'
#  'Pedagogik och undervisning' 'Kultur, media och design'
#  'Säkerhetstjänster' 'Samhällsbyggnad och byggteknik'
#  'Hotell, restaurang och turism'
#  'Lantbruk, djurvård, trädgård, skog och fiske' 'Teknik och tillverkning'
#  'Juridik' 'Hälso- och sjukvård samt socialt arbete'
#  'Journalistik och information' 'Friskvård och kroppsvård'
#  'Transporttjänster' 'Övrigt']
#
# Available counties:
# ['Västra Götaland' 'Se "Lista flera kommuner"' 'Stockholm'
#  'Västernorrland' 'Norrbotten' 'Skåne' 'Örebro' 'Södermanland' 'Uppsala'
#  'Kronoberg' 'Västerbotten' 'Gävleborg' 'Halland' 'Jönköping' 'Kalmar'
#  'Västmanland' 'Östergötland' 'Dalarna' 'Värmland' 'Jämtland' 'Blekinge']
#
# Hittade 57 kurser
# Filter:
#  - Utbildningsområde: Data/IT
#  - Län: Stockholm
#  - Kommun: Stockholm
# <style type="text/css">
# #T_72a27_row0_col0, #T_72a27_row0_col1, #T_72a27_row0_col2, #T_72a27_row0_col3, #T_72a27_row0_col4, #T_72a27_row0_col5, #T_72a27_row0_col6, #T_72a27_row1_col0, #T_72a27_row1_col1, #T_72a27_row1_col2, #T_72a27_row1_col3, #T_72a27_row1_col4, #T_72a27_row1_col5, #T_72a27_row1_col6, #T_72a27_row2_col0, #T_72a27_row2_col1, #T_72a27_row2_col2, #T_72a27_row2_col3, #T_72a27_row2_col4, #T_72a27_row2_col5, #T_72a27_row2_col6, #T_72a27_row3_col0, #T_72a27_row3_col1, #T_72a27_row3_col2, #T_72a27_row3_col3, #T_72a27_row3_col4, #T_72a27_row3_col5, #T_72a27_row3_col6, #T_72a27_row4_col0, #T_72a27_row4_col1, #T_72a27_row4_col2, #T_72a27_row4_col3, #T_72a27_row4_col4, #T_72a27_row4_col5, #T_72a27_row4_col6, #T_72a27_row5_col0, #T_72a27_row5_col1, #T_72a27_row5_col2, #T_72a27_row5_col3, #T_72a27_row5_col4, #T_72a27_row5_col5, #T_72a27_row5_col6, #T_72a27_row6_col0, #T_72a27_row6_col1, #T_72a27_row6_col2, #T_72a27_row6_col3, #T_72a27_row6_col4, #T_72a27_row6_col5, #T_72a27_row6_col6, #T_72a27_row7_col0, #T_72a27_row7_col1, #T_72a27_row7_col2, #T_72a27_row7_col3, #T_72a27_row7_col4, #T_72a27_row7_col5, #T_72a27_row7_col6, #T_72a27_row8_col0, #T_72a27_row8_col1, #T_72a27_row8_col2, #T_72a27_row8_col3, #T_72a27_row8_col4, #T_72a27_row8_col5, #T_72a27_row8_col6, #T_72a27_row9_col0, #T_72a27_row9_col1, #T_72a27_row9_col2, #T_72a27_row9_col3, #T_72a27_row9_col4, #T_72a27_row9_col5, #T_72a27_row9_col6, #T_72a27_row10_col0, #T_72a27_row10_col1, #T_72a27_row10_col2, #T_72a27_row10_col3, #T_72a27_row10_col4, #T_72a27_row10_col5, #T_72a27_row10_col6, #T_72a27_row11_col0, #T_72a27_row11_col1, #T_72a27_row11_col2, #T_72a27_row11_col3, #T_72a27_row11_col4, #T_72a27_row11_col5, #T_72a27_row11_col6, #T_72a27_row12_col0, #T_72a27_row12_col1, #T_72a27_row12_col2, #T_72a27_row12_col3, #T_72a27_row12_col4, #T_72a27_row12_col5, #T_72a27_row12_col6, #T_72a27_row13_col0, #T_72a27_row13_col1, #T_72a27_row13_col2, #T_72a27_row13_col3, #T_72a27_row13_col4, #T_72a27_row13_col5, #T_72a27_row13_col6, #T_72a27_row14_col0, #T_72a27_row14_col1, #T_72a27_row14_col2, #T_72a27_row14_col3, #T_72a27_row14_col4, #T_72a27_row14_col5, #T_72a27_row14_col6, #T_72a27_row15_col0, #T_72a27_row15_col1, #T_72a27_row15_col2, #T_72a27_row15_col3, #T_72a27_row15_col4, #T_72a27_row15_col5, #T_72a27_row15_col6, #T_72a27_row16_col0, #T_72a27_row16_col1, #T_72a27_row16_col2, #T_72a27_row16_col3, #T_72a27_row16_col4, #T_72a27_row16_col5, #T_72a27_row16_col6, #T_72a27_row17_col0, #T_72a27_row17_col1, #T_72a27_row17_col2, #T_72a27_row17_col3, #T_72a27_row17_col4, #T_72a27_row17_col5, #T_72a27_row17_col6, #T_72a27_row18_col0, #T_72a27_row18_col1, #T_72a27_row18_col2, #T_72a27_row18_col3, #T_72a27_row18_col4, #T_72a27_row18_col5, #T_72a27_row18_col6, #T_72a27_row19_col0, #T_72a27_row19_col1, #T_72a27_row19_col2, #T_72a27_row19_col3, #T_72a27_row19_col4, #T_72a27_row19_col5, #T_72a27_row19_col6, #T_72a27_row20_col0, #T_72a27_row20_col1, #T_72a27_row20_col2, #T_72a27_row20_col3, #T_72a27_row20_col4, #T_72a27_row20_col5, #T_72a27_row20_col6, #T_72a27_row21_col0, #T_72a27_row21_col1, #T_72a27_row21_col2, #T_72a27_row21_col3, #T_72a27_row21_col4, #T_72a27_row21_col5, #T_72a27_row21_col6, #T_72a27_row22_col0, #T_72a27_row22_col1, #T_72a27_row22_col2, #T_72a27_row22_col3, #T_72a27_row22_col4, #T_72a27_row22_col5, #T_72a27_row22_col6, #T_72a27_row23_col0, #T_72a27_row23_col1, #T_72a27_row23_col2, #T_72a27_row23_col3, #T_72a27_row23_col4, #T_72a27_row23_col5, #T_72a27_row23_col6, #T_72a27_row24_col0, #T_72a27_row24_col1, #T_72a27_row24_col2, #T_72a27_row24_col3, #T_72a27_row24_col4, #T_72a27_row24_col5, #T_72a27_row24_col6, #T_72a27_row25_col0, #T_72a27_row25_col1, #T_72a27_row25_col2, #T_72a27_row25_col3, #T_72a27_row25_col4, #T_72a27_row25_col5, #T_72a27_row25_col6, #T_72a27_row26_col0, #T_72a27_row26_col1, #T_72a27_row26_col2, #T_72a27_row26_col3, #T_72a27_row26_col4, #T_72a27_row26_col5, #T_72a27_row26_col6, #T_72a27_row27_col0, #T_72a27_row27_col1, #T_72a27_row27_col2, #T_72a27_row27_col3, #T_72a27_row27_co ...

# %% [markdown]
# ##### Enhanced School and Course Information Display
# The function now shows:
#
# - Number of education providers
# - Total courses
# - Approved courses
# - Total approved places
# - Per-provider statistics including approved places
# - Detailed course listing with place numbers

# %%
def filter_and_show_schools(df: pd.DataFrame,
                          education_area: str = None,
                          county: str = None,
                          municipality: str = None) -> pd.DataFrame:
    """
    Filter and display schools and their courses based on education area, county, and municipality.
    Returns detailed information about providers and their courses.
    """
    # Start with full dataset
    filtered_df = df.copy()
    
    # Apply filters if provided
    if education_area:
        filtered_df = filtered_df[filtered_df['Utbildningsområde'] == education_area]
    if county:
        filtered_df = filtered_df[filtered_df['Län'] == county]
    if municipality:
        filtered_df = filtered_df[filtered_df['Kommun'] == municipality]
    
    # Select and rename relevant columns
    result_df = filtered_df[[
        'Anordnare namn',
        'Utbildningsnamn',
        'Utbildningsområde',
        'Län',
        'Kommun',
        'YH-poäng',
        'Beslut'
    ]].copy()
    
    # Rename columns for better readability
    result_df.columns = [
        'Skola',
        'Kursnamn',
        'Utbildningsområde',
        'Län',
        'Kommun',
        'YH-poäng',
        'Beslut'
    ]
    
    # Sort by school name and course name
    result_df = result_df.sort_values(['Skola', 'Kursnamn'])
    
    return result_df

def show_filtered_schools(df: pd.DataFrame,
                        education_area: str = None,
                        county: str = None,
                        municipality: str = None) -> None:
    """
    Display filtered school and course information with enhanced statistics.
    """
    result = filter_and_show_schools(df, education_area, county, municipality)
    
    if result.empty:
        print("Inga resultat hittades med angivna filter.")
        return
    
    # Calculate statistics
    total_courses = len(result)
    total_providers = result['Skola'].nunique()
    approved_courses = len(result[result['Beslut'] == 'Beviljad'])
    
    # Print summary statistics
    print(f"\nSammanfattning:")
    print(f"Antal utbildningsanordnare: {total_providers}")
    print(f"Totalt antal kurser: {total_courses}")
    print(f"Antal beviljade kurser: {approved_courses}")
    
    # Print filter criteria
    print(f"\nFilter: ", end="")
    if education_area:
        print(f"\n - Utbildningsområde: {education_area}", end="")
    if county:
        print(f"\n - Län: {county}", end="")
    if municipality:
        print(f"\n - Kommun: {municipality}", end="")
    print("\n")
    
    # Group by provider and show course counts
    provider_summary = result.groupby('Skola').agg({
        'Kursnamn': 'count',
        'Beslut': lambda x: (x == 'Beviljad').sum()
    }).rename(columns={
        'Kursnamn': 'Antal kurser',
        'Beslut': 'Beviljade kurser'
    })
    
    print("Statistik per utbildningsanordnare:")
    display(provider_summary)
    
    print("\nDetaljerad information om kurser:")
    # Display detailed course information
    display(result.style
           .set_properties(**{
               'background-color': 'white',
               'color': 'black',
               'border-color': '#888'
           })
           .hide(axis='index')
    )

# Example usage:
print("Available education areas:")
print(df['Utbildningsområde'].unique())
print("\nAvailable counties:")
print(df['Län'].unique())

# Example filter
show_filtered_schools(
    df,
    education_area="Data/IT",
    county="Stockholm",
    municipality="Stockholm"
)
# Out:
# Available education areas:
# ['Ekonomi, administration och försäljning' 'Data/IT'
#  'Pedagogik och undervisning' 'Kultur, media och design'
#  'Säkerhetstjänster' 'Samhällsbyggnad och byggteknik'
#  'Hotell, restaurang och turism'
#  'Lantbruk, djurvård, trädgård, skog och fiske' 'Teknik och tillverkning'
#  'Juridik' 'Hälso- och sjukvård samt socialt arbete'
#  'Journalistik och information' 'Friskvård och kroppsvård'
#  'Transporttjänster' 'Övrigt']
#
# Available counties:
# ['Västra Götaland' 'Se "Lista flera kommuner"' 'Stockholm'
#  'Västernorrland' 'Norrbotten' 'Skåne' 'Örebro' 'Södermanland' 'Uppsala'
#  'Kronoberg' 'Västerbotten' 'Gävleborg' 'Halland' 'Jönköping' 'Kalmar'
#  'Västmanland' 'Östergötland' 'Dalarna' 'Värmland' 'Jämtland' 'Blekinge']
#
# Sammanfattning:
# Antal utbildningsanordnare: 22
# Totalt antal kurser: 57
# Antal beviljade kurser: 32
#
# Filter:
#  - Utbildningsområde: Data/IT
#  - Län: Stockholm
#  - Kommun: Stockholm
#
# Statistik per utbildningsanordnare:
#                                                     Antal kurser  \
# Skola
# ABF-S Avdelning i Stockholm                                    1
# Chas Academy AB                                                2
# EC Utbildning AB Stockholm                                     3
# EdUP Group AB                                                  1
# Futuregames Stockholm                                          2
# Företagsekonomiska Institutet 1888 AB                          2
# Företagsuniversitetet AB                                       3
# Hermods AB Stockholm                                           2
# Hyper Island Program AB - Stockholm                            1
# IT-Högskolan Stockholm AB                                      6
# KYH AB                                                         1
# Kunskapsgruppen Yrkeshögskola Sverige AB                       1
# Lernia Utbildning AB                                           3
# Lexicon Yrkeshögskola AB                                       7
# Medborgarskolan i Stockholm - Påhlmans Handelsi...             2
# Medieinstitutet i Sverige AB                                   7
# Revly AB                                                       2
# Stiftelsen Stockholms Tekniska Institut                        5
# Stockholm School of Business                                   1
# Stockholms Internationella Handelsskola AB                     1
# Stockholms stad, Frans Schartaus Handelsinstitut               3
# Sveriges Yrkeshögskola AB - Stockholm Yrkeshögs...             1
#
#                                                     Beviljade kurser
# Skola
# ABF-S Avdelning i Stockholm                                        0
# Chas Academy AB                                                    1
# EC Utbildning AB Stockholm                                         2
# EdUP Group AB                                                      0
# Futuregames Stockholm                                              0
# Företagsekonomiska Institutet 1888 AB                              0
# Företagsuniversitetet AB                                           2
# Hermods AB Stockholm                                               0
# Hyper Island Program AB - Stockholm                                1
# IT-Högskolan Stockholm AB                                          5
# KYH AB                                                             0
# Kunskapsgruppen Yrkeshögskola Sverige AB                           0
# Lernia Utbildning AB                                               3
# Lexicon Yrkeshögskola AB                                           3
# Medborgarskolan i Stockholm - Påhlmans Handelsi...                 0
# Medieinstitutet i Sverige AB                                       6
# Revly AB                                                           0
# Stiftelsen Stockholms Tekniska Institut                            4
# Stockholm School of Business                                       1
# Stockholms Internationella Handelsskola AB                         1
# Stockholms stad, Frans Schartaus Handelsinstitut                   3
# Sveriges Yrkeshögskola AB - Stockholm Yrkeshögs...                 0
# Detaljerad information om kurser:
# <style type="text/css">
# #T_bfb4e_row0_col0, #T_bfb4e_row0_col1, #T_bfb4e_row0_col2, #T_bfb4e_row0_col3, #T_bfb4e_row0_col4, #T_bfb4e_row0_col5, #T_bfb4e_row0_col6, #T_bfb4e_row1_col0, #T_bfb4e_row1_col1, #T_bfb4e_row1_col2, #T_bfb4e_row1_col3, #T_bfb4e_row1_col4, #T_bfb4e_row1_col5, #T_bfb4e_row1_col6, #T_bfb4e_row2_col0, #T_bfb4e_row2_col1, #T_bfb4e_row2_col2, #T_bfb4e_row2_col3, #T_bfb4e_row2_col4, #T_bfb4e_row2_col5, #T_bfb4e_row2_col6, #T_bfb4e_row3_col0, #T_bfb4e_row3_col1, #T_bfb4e_row3_col2, #T_bfb4e_row3_col3, #T_bfb4e_row3_col4, #T_bfb4e_row3_col5, #T_bfb4e_row3_col6, #T_bfb4e_row4_col0, #T_bfb4e_row4_col1, #T_bfb4e_row4_col2, #T_bfb4e_row4_col3, #T_bfb4e_row4_col4, #T_bfb4e_row4_col5, #T_bfb4e_row4_col6, #T_bfb4e_row5_col0, #T_bfb4e_row5_col1, #T_bfb4e_row5_col2, #T_bfb4e_row5_col3, #T_bfb4e_row5_col4, #T_bfb4e_row5_col5, #T_bfb4e_row5_col6, #T_bfb4e_row6_col0, #T_bfb4e_row6_col1, #T_bfb4e_row6_col2, #T_bfb4e_row6_col3, #T_bfb4e_row6_col4, #T_bfb4e_row6_col5, #T_bfb4e_row6_col6, #T_bfb4e_row7_col0, #T_bfb4e_row7_col1, #T_bfb4e_row7_col2, #T_bfb4e_row7_col3, #T_bfb4e_row7_col4, #T_bfb4e_row7_col5, #T_bfb4e_row7_col6, #T_bfb4e_row8_col0, #T_bfb4e_row8_col1, #T_bfb4e_row8_col2, #T_bfb4e_row8_col3, #T_bfb4e_row8_col4, #T_bfb4e_row8_col5, #T_bfb4e_row8_col6, #T_bfb4e_row9_col0, #T_bfb4e_row9_col1, #T_bfb4e_row9_col2, #T_bfb4e_row9_col3, #T_bfb4e_row9_col4, #T_bfb4e_row9_col5, #T_bfb4e_row9_col6, #T_bfb4e_row10_col0, #T_bfb4e_row10_col1, #T_bfb4e_row10_col2, #T_bfb4e_row10_col3, #T_bfb4e_row10_col4, #T_bfb4e_row10_col5, #T_bfb4e_row10_col6, #T_bfb4e_row11_col0, #T_bfb4e_row11_col1, #T_bfb4e_row11_col2, #T_bfb4e_row11_col3, #T_bfb4e_row11_col4, #T_bfb4e_row11_col5, #T_bfb4e_row11_col6, #T_bfb4e_row12_col0, #T_bfb4e_row12_col1, #T_bfb4e_row12_col2, #T_bfb4e_row12_col3, #T_bfb4e_row12_col4, #T_bfb4e_row12_col5, #T_bfb4e_row12_col6, #T_bfb4e_row13_col0, #T_bfb4e_row13_col1, #T_bfb4e_row13_col2, #T_bfb4e_row13_col3, #T_bfb4e_row13_col4, #T_bfb4e_row13_col5, #T_bfb4e_row13_col6, #T_bfb4e_row14_col0, #T_bfb4e_row14_col1, #T_bfb4e_row14_col2, #T_bfb4e_row14_col3, #T_bfb4e_row14_col4, #T_bfb4e_row14_col5, #T_bfb4e_row14_col6, #T_bfb4e_row15_col0, #T_bfb4e_row15_col1, #T_bfb4e_row15_col2, #T_bfb4e_row15_col3, #T_bfb4e_row15_col4, #T_bfb4e_row15_col5, #T_bfb4e_row15_col6, #T_bfb4e_row16_col0, #T_bfb4e_row16_col1, #T_bfb4e_row16_col2, #T_bfb4e_row16_col3, #T_bfb4e_row16_col4, #T_bfb4e_row16_col5, #T_bfb4e_row16_col6, #T_bfb4e_row17_col0, #T_bfb4e_row17_col1, #T_bfb4e_row17_col2, #T_bfb4e_row17_col3, #T_bfb4e_row17_col4, #T_bfb4e_row17_col5, #T_bfb4e_row17_col6, #T_bfb4e_row18_col0, #T_bfb4e_row18_col1, #T_bfb4e_row18_col2, #T_bfb4e_row18_col3, #T_bfb4e_row18_col4, #T_bfb4e_row18_col5, #T_bfb4e_row18_col6, #T_bfb4e_row19_col0, #T_bfb4e_row19_col1, #T_bfb4e_row19_col2, #T_bfb4e_row19_col3, #T_bfb4e_row19_col4, #T_bfb4e_row19_col5, #T_bfb4e_row19_col6, #T_bfb4e_row20_col0, #T_bfb4e_row20_col1, #T_bfb4e_row20_col2, #T_bfb4e_row20_col3, #T_bfb4e_row20_col4, #T_bfb4e_row20_col5, #T_bfb4e_row20_col6, #T_bfb4e_row21_col0, #T_bfb4e_row21_col1, #T_bfb4e_row21_col2, #T_bfb4e_row21_col3, #T_bfb4e_row21_col4, #T_bfb4e_row21_col5, #T_bfb4e_row21_col6, #T_bfb4e_row22_col0, #T_bfb4e_row22_col1, #T_bfb4e_row22_col2, #T_bfb4e_row22_col3, #T_bfb4e_row22_col4, #T_bfb4e_row22_col5, #T_bfb4e_row22_col6, #T_bfb4e_row23_col0, #T_bfb4e_row23_col1, #T_bfb4e_row23_col2, #T_bfb4e_row23_col3, #T_bfb4e_row23_col4, #T_bfb4e_row23_col5, #T_bfb4e_row23_col6, #T_bfb4e_row24_col0, #T_bfb4e_row24_col1, #T_bfb4e_row24_col2, #T_bfb4e_row24_col3, #T_bfb4e_row24_col4, #T_bfb4e_row24_col5, #T_bfb4e_row24_col6, #T_bfb4e_row25_col0, #T_bfb4e_row25_col1, #T_bfb4e_row25_col2, #T_bfb4e_row25_col3, #T_bfb4e_row25_col4, #T_bfb4e_row25_col5, #T_bfb4e_row25_col6, #T_bfb4e_row26_col0, #T_bfb4e_row26_col1, #T_bfb4e_row26_col2, #T_bfb4e_row26_col3, #T_bfb4e_row26_col4, #T_bfb4e_row26_col5, #T_bfb4e_row26_col6, #T_bfb4e_row27_col0, #T_bfb4e_row27_col1, #T_bfb4e_row27_col2, #T_bfb4e_row27_col3, #T_bfb4e_row27_co ...

# %% [markdown]
# ##### Key Features:
# Summary Statistics:
#
# - Number of education providers
#     - Total courses
#     - Number of approved courses
#     - Total approved places
#
# - Provider Summary Table:
#     - School name
#     - Total courses
#     - Approved courses
#     - Total approved places
#
# - Detailed Course Information:
#     - School name
#     - Course name
#     - Education area
#     - County
#     - Municipality
#     - YH credits
#     - Decision status
#     - Approved places
#
# - Filtering Options:
#     - By education area
#     - By county
#     - By municipality

# %%
def filter_and_show_schools(df: pd.DataFrame,
                          education_area: str = None,
                          county: str = None,
                          municipality: str = None) -> pd.DataFrame:
    """
    Filter and display schools and their courses based on education area, county, and municipality.
    Returns detailed information about providers and their courses.
    """
    # Start with full dataset
    filtered_df = df.copy()
    
    # Apply filters if provided
    if education_area:
        filtered_df = filtered_df[filtered_df['Utbildningsområde'] == education_area]
    if county:
        filtered_df = filtered_df[filtered_df['Län'] == county]
    if municipality:
        filtered_df = filtered_df[filtered_df['Kommun'] == municipality]
    
    # Select and rename relevant columns
    result_df = filtered_df[[
        'Anordnare namn',
        'Utbildningsnamn',
        'Utbildningsområde',
        'Län',
        'Kommun',
        'YH-poäng',
        'Beslut',
        'Totalt antal beviljade platser'
    ]].copy()
    
    # Rename columns for better readability
    result_df.columns = [
        'Skola',
        'Kursnamn',
        'Utbildningsområde',
        'Län',
        'Kommun',
        'YH-poäng',
        'Beslut',
        'Beviljade platser'
    ]
    
    # Sort by school name and course name
    result_df = result_df.sort_values(['Skola', 'Kursnamn'])
    
    return result_df

def show_filtered_schools(df: pd.DataFrame,
                        education_area: str = None,
                        county: str = None,
                        municipality: str = None) -> None:
    """
    Display filtered school and course information with enhanced statistics.
    """
    result = filter_and_show_schools(df, education_area, county, municipality)
    
    if result.empty:
        print("Inga resultat hittades med angivna filter.")
        return
    
    # Calculate statistics
    total_courses = len(result)
    total_providers = result['Skola'].nunique()
    approved_courses = len(result[result['Beslut'] == 'Beviljad'])
    total_places = result[result['Beslut'] == 'Beviljad']['Beviljade platser'].sum()
    
    # Print summary statistics
    print(f"\nSammanfattning:")
    print(f"Antal utbildningsanordnare: {total_providers}")
    print(f"Totalt antal kurser: {total_courses}")
    print(f"Antal beviljade kurser: {approved_courses}")
    print(f"Totalt antal beviljade platser: {total_places}")
    
    # Print filter criteria
    print(f"\nFilter: ", end="")
    if education_area:
        print(f"\n - Utbildningsområde: {education_area}", end="")
    if county:
        print(f"\n - Län: {county}", end="")
    if municipality:
        print(f"\n - Kommun: {municipality}", end="")
    print("\n")
    
    # Group by provider and show course counts
    provider_summary = result.groupby('Skola').agg({
        'Kursnamn': 'count',
        'Beslut': lambda x: (x == 'Beviljad').sum(),
        'Beviljade platser': 'sum'
    }).rename(columns={
        'Kursnamn': 'Antal kurser',
        'Beslut': 'Beviljade kurser',
        'Beviljade platser': 'Totalt beviljade platser'
    })
    
    print("Statistik per utbildningsanordnare:")
    display(provider_summary)
    
    print("\nDetaljerad information om kurser:")
    # Display detailed course information
    display(result.style
           .set_properties(**{
               'background-color': 'white',
               'color': 'black',
               'border-color': '#888'
           })
           .hide(axis='index')
    )

# Example usage:
print("Available education areas:")
print(df['Utbildningsområde'].unique())
print("\nAvailable counties:")
print(df['Län'].unique())
# Out:
# Available education areas:
# ['Ekonomi, administration och försäljning' 'Data/IT'
#  'Pedagogik och undervisning' 'Kultur, media och design'
#  'Säkerhetstjänster' 'Samhällsbyggnad och byggteknik'
#  'Hotell, restaurang och turism'
#  'Lantbruk, djurvård, trädgård, skog och fiske' 'Teknik och tillverkning'
#  'Juridik' 'Hälso- och sjukvård samt socialt arbete'
#  'Journalistik och information' 'Friskvård och kroppsvård'
#  'Transporttjänster' 'Övrigt']
#
# Available counties:
# ['Västra Götaland' 'Se "Lista flera kommuner"' 'Stockholm'
#  'Västernorrland' 'Norrbotten' 'Skåne' 'Örebro' 'Södermanland' 'Uppsala'
#  'Kronoberg' 'Västerbotten' 'Gävleborg' 'Halland' 'Jönköping' 'Kalmar'
#  'Västmanland' 'Östergötland' 'Dalarna' 'Värmland' 'Jämtland' 'Blekinge']

# %%
# Example filter
show_filtered_schools(
    df,
    education_area="Data/IT",
    county="Stockholm",
    municipality="Stockholm"
)
# Out:
# Sammanfattning:
# Antal utbildningsanordnare: 22
# Totalt antal kurser: 57
# Antal beviljade kurser: 32
# Totalt antal beviljade platser: 2260
#
# Filter:
#  - Utbildningsområde: Data/IT
#  - Län: Stockholm
#  - Kommun: Stockholm
#
# Statistik per utbildningsanordnare:
#                                                     Antal kurser  \
# Skola
# ABF-S Avdelning i Stockholm                                    1
# Chas Academy AB                                                2
# EC Utbildning AB Stockholm                                     3
# EdUP Group AB                                                  1
# Futuregames Stockholm                                          2
# Företagsekonomiska Institutet 1888 AB                          2
# Företagsuniversitetet AB                                       3
# Hermods AB Stockholm                                           2
# Hyper Island Program AB - Stockholm                            1
# IT-Högskolan Stockholm AB                                      6
# KYH AB                                                         1
# Kunskapsgruppen Yrkeshögskola Sverige AB                       1
# Lernia Utbildning AB                                           3
# Lexicon Yrkeshögskola AB                                       7
# Medborgarskolan i Stockholm - Påhlmans Handelsi...             2
# Medieinstitutet i Sverige AB                                   7
# Revly AB                                                       2
# Stiftelsen Stockholms Tekniska Institut                        5
# Stockholm School of Business                                   1
# Stockholms Internationella Handelsskola AB                     1
# Stockholms stad, Frans Schartaus Handelsinstitut               3
# Sveriges Yrkeshögskola AB - Stockholm Yrkeshögs...             1
#
#                                                     Beviljade kurser  \
# Skola
# ABF-S Avdelning i Stockholm                                        0
# Chas Academy AB                                                    1
# EC Utbildning AB Stockholm                                         2
# EdUP Group AB                                                      0
# Futuregames Stockholm                                              0
# Företagsekonomiska Institutet 1888 AB                              0
# Företagsuniversitetet AB                                           2
# Hermods AB Stockholm                                               0
# Hyper Island Program AB - Stockholm                                1
# IT-Högskolan Stockholm AB                                          5
# KYH AB                                                             0
# Kunskapsgruppen Yrkeshögskola Sverige AB                           0
# Lernia Utbildning AB                                               3
# Lexicon Yrkeshögskola AB                                           3
# Medborgarskolan i Stockholm - Påhlmans Handelsi...                 0
# Medieinstitutet i Sverige AB                                       6
# Revly AB                                                           0
# Stiftelsen Stockholms Tekniska Institut                            4
# Stockholm School of Business                                       1
# Stockholms Internationella Handelsskola AB                         1
# Stockholms stad, Frans Schartaus Handelsinstitut                   3
# Sveriges Yrkeshögskola AB - Stockholm Yrkeshögs...                 0
#
#                                                     Totalt beviljade platser
# Skola
# ABF-S Avdelning i Stockholm                                                0
# Chas Academy AB                                                           50
# EC Utbildning AB Stockholm                                                70
# EdUP Group AB                                                              0
# Futuregames Stockholm                                                      0
# Företagsekonomiska Institutet 1888 AB                                      0
# Företagsuniversitetet AB                                                 305
# Hermods AB Stockholm                                                       0
# Hyper Island Program AB - Stockholm                                      110
# IT-Högskolan Stockholm AB                                                260
# KYH AB                                                                     0
# Kunskapsgruppen Yrkeshögskola Sverige AB                                   0
# Lernia Utbildning AB                                                     200
# Lexicon Yrkeshögskola AB                                                 230
# Medborgarskolan i Stockholm - Påhlmans Handelsi...                         0
# Medieinstitutet i Sverige AB                                             366
# Revly AB                                                                   0
# Stiftelsen Stockholms Tekniska Institut                                  310
# Stockholm School of Business                                             120
# Stockholms Internationella Handelsskola AB                                64
# Stockholms stad, Frans Schartaus Handelsinstitut                         175
# Sveriges Yrkeshögskola AB - Stockholm Yrkeshögs...                         0
# Detaljerad information om kurser:
# <style type="text/css">
# #T_c4814_row0_col0, #T_c4814_row0_col1, #T_c4814_row0_col2, #T_c4814_row0_col3, #T_c4814_row0_col4, #T_c4814_row0_col5, #T_c4814_row0_col6, #T_c4814_row0_col7, #T_c4814_row1_col0, #T_c4814_row1_col1, #T_c4814_row1_col2, #T_c4814_row1_col3, #T_c4814_row1_col4, #T_c4814_row1_col5, #T_c4814_row1_col6, #T_c4814_row1_col7, #T_c4814_row2_col0, #T_c4814_row2_col1, #T_c4814_row2_col2, #T_c4814_row2_col3, #T_c4814_row2_col4, #T_c4814_row2_col5, #T_c4814_row2_col6, #T_c4814_row2_col7, #T_c4814_row3_col0, #T_c4814_row3_col1, #T_c4814_row3_col2, #T_c4814_row3_col3, #T_c4814_row3_col4, #T_c4814_row3_col5, #T_c4814_row3_col6, #T_c4814_row3_col7, #T_c4814_row4_col0, #T_c4814_row4_col1, #T_c4814_row4_col2, #T_c4814_row4_col3, #T_c4814_row4_col4, #T_c4814_row4_col5, #T_c4814_row4_col6, #T_c4814_row4_col7, #T_c4814_row5_col0, #T_c4814_row5_col1, #T_c4814_row5_col2, #T_c4814_row5_col3, #T_c4814_row5_col4, #T_c4814_row5_col5, #T_c4814_row5_col6, #T_c4814_row5_col7, #T_c4814_row6_col0, #T_c4814_row6_col1, #T_c4814_row6_col2, #T_c4814_row6_col3, #T_c4814_row6_col4, #T_c4814_row6_col5, #T_c4814_row6_col6, #T_c4814_row6_col7, #T_c4814_row7_col0, #T_c4814_row7_col1, #T_c4814_row7_col2, #T_c4814_row7_col3, #T_c4814_row7_col4, #T_c4814_row7_col5, #T_c4814_row7_col6, #T_c4814_row7_col7, #T_c4814_row8_col0, #T_c4814_row8_col1, #T_c4814_row8_col2, #T_c4814_row8_col3, #T_c4814_row8_col4, #T_c4814_row8_col5, #T_c4814_row8_col6, #T_c4814_row8_col7, #T_c4814_row9_col0, #T_c4814_row9_col1, #T_c4814_row9_col2, #T_c4814_row9_col3, #T_c4814_row9_col4, #T_c4814_row9_col5, #T_c4814_row9_col6, #T_c4814_row9_col7, #T_c4814_row10_col0, #T_c4814_row10_col1, #T_c4814_row10_col2, #T_c4814_row10_col3, #T_c4814_row10_col4, #T_c4814_row10_col5, #T_c4814_row10_col6, #T_c4814_row10_col7, #T_c4814_row11_col0, #T_c4814_row11_col1, #T_c4814_row11_col2, #T_c4814_row11_col3, #T_c4814_row11_col4, #T_c4814_row11_col5, #T_c4814_row11_col6, #T_c4814_row11_col7, #T_c4814_row12_col0, #T_c4814_row12_col1, #T_c4814_row12_col2, #T_c4814_row12_col3, #T_c4814_row12_col4, #T_c4814_row12_col5, #T_c4814_row12_col6, #T_c4814_row12_col7, #T_c4814_row13_col0, #T_c4814_row13_col1, #T_c4814_row13_col2, #T_c4814_row13_col3, #T_c4814_row13_col4, #T_c4814_row13_col5, #T_c4814_row13_col6, #T_c4814_row13_col7, #T_c4814_row14_col0, #T_c4814_row14_col1, #T_c4814_row14_col2, #T_c4814_row14_col3, #T_c4814_row14_col4, #T_c4814_row14_col5, #T_c4814_row14_col6, #T_c4814_row14_col7, #T_c4814_row15_col0, #T_c4814_row15_col1, #T_c4814_row15_col2, #T_c4814_row15_col3, #T_c4814_row15_col4, #T_c4814_row15_col5, #T_c4814_row15_col6, #T_c4814_row15_col7, #T_c4814_row16_col0, #T_c4814_row16_col1, #T_c4814_row16_col2, #T_c4814_row16_col3, #T_c4814_row16_col4, #T_c4814_row16_col5, #T_c4814_row16_col6, #T_c4814_row16_col7, #T_c4814_row17_col0, #T_c4814_row17_col1, #T_c4814_row17_col2, #T_c4814_row17_col3, #T_c4814_row17_col4, #T_c4814_row17_col5, #T_c4814_row17_col6, #T_c4814_row17_col7, #T_c4814_row18_col0, #T_c4814_row18_col1, #T_c4814_row18_col2, #T_c4814_row18_col3, #T_c4814_row18_col4, #T_c4814_row18_col5, #T_c4814_row18_col6, #T_c4814_row18_col7, #T_c4814_row19_col0, #T_c4814_row19_col1, #T_c4814_row19_col2, #T_c4814_row19_col3, #T_c4814_row19_col4, #T_c4814_row19_col5, #T_c4814_row19_col6, #T_c4814_row19_col7, #T_c4814_row20_col0, #T_c4814_row20_col1, #T_c4814_row20_col2, #T_c4814_row20_col3, #T_c4814_row20_col4, #T_c4814_row20_col5, #T_c4814_row20_col6, #T_c4814_row20_col7, #T_c4814_row21_col0, #T_c4814_row21_col1, #T_c4814_row21_col2, #T_c4814_row21_col3, #T_c4814_row21_col4, #T_c4814_row21_col5, #T_c4814_row21_col6, #T_c4814_row21_col7, #T_c4814_row22_col0, #T_c4814_row22_col1, #T_c4814_row22_col2, #T_c4814_row22_col3, #T_c4814_row22_col4, #T_c4814_row22_col5, #T_c4814_row22_col6, #T_c4814_row22_col7, #T_c4814_row23_col0, #T_c4814_row23_col1, #T_c4814_row23_col2, #T_c4814_row23_col3, #T_c4814_row23_col4, #T_c4814_row23_col5, #T_c4814_row23_col6, #T_c4814_row23_col7, #T_c4814_row24_col0, #T_c4814_row24_col1, #T_c48 ...
